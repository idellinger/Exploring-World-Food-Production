# %% [markdown]
# # Exploring World Food Production

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = 'world food production.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#         Entity  Year  Maize Production (tonnes)  Rice  Production ( tonnes)  \
# 0  Afghanistan  1961                   700000.0                    319000.0
# 1  Afghanistan  1962                   700000.0                    319000.0
# 2  Afghanistan  1963                   713000.0                    319000.0
# 3  Afghanistan  1964                   720000.0                    380000.0
# 4  Afghanistan  1965                   720000.0                    380000.0
#
#    Yams  Production (tonnes)  Wheat Production (tonnes)  \
# 0                  7467702.0                  2279000.0
# 1                  7420515.0                  2279000.0
# 2                  8479074.0                  1947000.0
# 3                  9113779.0                  2230000.0
# 4                 10067913.0                  2282000.0
#
#    Tomatoes Production (tonnes)  Tea  Production ( tonnes )  \
# 0                     1873812.0                     56315.0
# ...

# %%
df.keys()
# Out:
# Index(['Entity', 'Year', 'Maize Production (tonnes)',
#        'Rice  Production ( tonnes)', 'Yams  Production (tonnes)',
#        'Wheat Production (tonnes)', 'Tomatoes Production (tonnes)',
#        'Tea  Production ( tonnes )', 'Sweet potatoes  Production (tonnes)',
#        'Sunflower seed  Production (tonnes)', 'Sugar cane Production (tonnes)',
#        'Soybeans  Production (tonnes)', 'Rye  Production (tonnes)',
#        'Potatoes  Production (tonnes)', 'Oranges  Production (tonnes)',
#        'Peas, dry Production ( tonnes)', 'Palm oil  Production (tonnes)',
#        'Grapes  Production (tonnes)', 'Coffee, green Production ( tonnes)',
#        'Cocoa beans Production (tonnes)', 'Meat, chicken  Production (tonnes)',
#        'Bananas  Production ( tonnes)', 'Avocados Production (tonnes)',
#        'Apples Production (tonnes)'],
#       dtype='object')

# %%
# Renaming columns for consistency and workability 
df.columns = ['Country', 'Year', 'Maize','Rice','Yams','Wheat','Tomatoes','Tea','Sweet Potatoes','Sunflower Seeds','Sugar','Soybeans','Rye','Potatoes','Oranges','Peas','Palm Oil','Grapes','Coffee','Cocoa','Chicken','Bananas','Avocados','Apples']
df.head()
# Out:
#        Country  Year     Maize      Rice        Yams      Wheat   Tomatoes  \
# 0  Afghanistan  1961  700000.0  319000.0   7467702.0  2279000.0  1873812.0
# 1  Afghanistan  1962  700000.0  319000.0   7420515.0  2279000.0  2044797.0
# 2  Afghanistan  1963  713000.0  319000.0   8479074.0  1947000.0  2096077.0
# 3  Afghanistan  1964  720000.0  380000.0   9113779.0  2230000.0  2388264.0
# 4  Afghanistan  1965  720000.0  380000.0  10067913.0  2282000.0  2559608.0
#
#        Tea  Sweet Potatoes  Sunflower Seeds  ...  Oranges      Peas  \
# 0  56315.0       3270871.0          12000.0  ...  10100.0  232910.0
# 1  61519.0       3562524.0          12800.0  ...  10100.0  259412.0
# 2  63596.0       3409916.0          12800.0  ...  10100.0  251529.0
# 3  66604.0       3229336.0          12800.0  ...  12400.0  247556.0
# 4  72418.0       3169104.0          13200.0  ...  13700.0  266947.0
#
#     Palm Oil    Grapes     Coffee      Cocoa  Chicken    Bananas  Avocados  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11912 entries, 0 to 11911
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          11912 non-null  object
#  1   Year             11912 non-null  int64
#  2   Maize            11912 non-null  float64
#  3   Rice             11912 non-null  float64
#  4   Yams             11912 non-null  float64
#  5   Wheat            11912 non-null  float64
#  6   Tomatoes         11912 non-null  float64
#  7   Tea              11912 non-null  float64
#  8   Sweet Potatoes   11912 non-null  float64
#  9   Sunflower Seeds  11912 non-null  float64
#  10  Sugar            11912 non-null  float64
#  11  Soybeans         11912 non-null  float64
#  12  Rye              11912 non-null  float64
#  13  Potatoes         11912 non-null  float64
#  14  Oranges          11912 non-null  float64
#  15  Peas             11912 non-null  float64
# ...

# %%
df.describe()
# Out:
#                Year         Maize          Rice          Yams         Wheat  \
# count  11912.000000  1.191200e+04  1.191200e+04  1.191200e+04  1.191200e+04
# mean    1992.115346  1.926434e+07  2.254542e+07  2.744973e+06  2.365684e+07
# std       17.606091  7.028022e+07  7.749779e+07  8.787786e+06  6.177899e+07
# min     1961.000000  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     1977.000000  2.379300e+04  3.902475e+04  1.176250e+04  8.892500e+04
# 50%     1993.000000  4.000490e+05  4.543745e+05  1.236055e+05  1.650000e+06
# 75%     2007.000000  4.979875e+06  4.440542e+06  5.721030e+05  1.524149e+07
# max     2021.000000  1.210235e+09  7.872939e+08  7.871405e+07  7.723055e+08
#
#            Tomatoes           Tea  Sweet Potatoes  Sunflower Seeds  \
# count  1.191200e+04  1.191200e+04    1.191200e+04     1.191200e+04
# mean   3.238661e+06  1.350523e+05    5.021303e+06     1.410297e+06
# std    1.146992e+07  2.544264e+05    2.001692e+07     3.625725e+06
# ...

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# Country            0
# Year               0
# Maize              0
# Rice               0
# Yams               0
# Wheat              0
# Tomatoes           0
# Tea                0
# Sweet Potatoes     0
# Sunflower Seeds    0
# Sugar              0
# Soybeans           0
# Rye                0
# Potatoes           0
# Oranges            0
# Peas               0
# Palm Oil           0
# Grapes             0
# Coffee             0
# Cocoa              0
# Chicken            0
# Bananas            0
# Avocados           0
# Apples             0
# dtype: int64

# %%
pd.options.display.max_rows = 500
df['Country'].value_counts()
# Out:
# Country
# Afghanistan                                      61
# Nicaragua                                        61
# Morocco                                          61
# Mozambique                                       61
# Myanmar                                          61
# Namibia                                          61
# Nepal                                            61
# Net Food Importing Developing Countries (FAO)    61
# Netherlands                                      61
# New Caledonia                                    61
# New Zealand                                      61
# Niger                                            61
# Mexico                                           61
# Nigeria                                          61
# North America                                    61
# North Korea                                      61
# Northern Africa (FAO)                            61
# Northern America (FAO)                           61
# ...

# %%
# Potential regions/groupings of countries that could effect the data
grouping_rows_ignore = ['Net Food Importing Developing Countries (FAO)','Northern Africa (FAO)','Northern America (FAO)','Oceania (FAO)','Middle Africa (FAO)',
                    'Land Locked Developing Countries (FAO)','Least Developed Countries (FAO)','Low Income Food Deficit Countries (FAO)',
                    'Low-income countries','Lower-middle-income countries','Upper-middle-income countries','Western Africa (FAO)','Western Asia (FAO)','Western Europe (FAO)',
                    'Small Island Developing States (FAO)','South America (FAO)','South America','South-eastern Asia (FAO)','Southern Africa (FAO)','Southern Asia (FAO)','Southern Europe (FAO)',
                    'China (FAO)','Central America (FAO)','Eastern Europe (FAO)','Eastern Africa (FAO)','Africa (FAO)','Americas (FAO)','Asia (FAO)','Eastern Asia (FAO)','European Union (27)',
                    'High-income countries','European Union (27) (FAO)','Europe (FAO)','Northern Europe (FAO)','Belgium-Luxembourg (FAO)','Micronesia (FAO)','Central Asia (FAO)'
]
# Create a boolean mask to filter rows
mask_grouping_rows = df['Country'].isin(grouping_rows_ignore)

# Create a new DataFrame with only the specified rows
df_grouping_rows = df[mask_grouping_rows]

# Display the resulting DataFrame
print(df_grouping_rows)
# Out:
#                     Country  Year       Maize       Rice        Yams  \
# 122            Africa (FAO)  1961  16147243.0  4309840.0  475673.000
# 123            Africa (FAO)  1962  17572218.0  5581664.0  493705.000
# 124            Africa (FAO)  1963  17649652.0  5814128.0  510266.000
# 125            Africa (FAO)  1964  16171887.0  5834832.0  526498.000
# 126            Africa (FAO)  1965  16946728.0  5473411.0  526826.000
# ...                     ...   ...         ...        ...         ...
# 11632  Western Europe (FAO)  2017  22047012.0  1479259.0   10615.840
# 11633  Western Europe (FAO)  2018  18656212.0  2891806.6  841115.980
# 11634  Western Europe (FAO)  2019  19561508.0  2906980.8  341974.200
# 11635  Western Europe (FAO)  2020  20658222.0  1629888.0  237139.916
# 11636  Western Europe (FAO)  2021  22975586.0   118330.2  275510.856
#
#             Wheat  Tomatoes        Tea  Sweet Potatoes  Sunflower Seeds  ...  \
# ...

# %%
df_grouping_rows.info()
()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2154 entries, 122 to 11636
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          2154 non-null   object
#  1   Year             2154 non-null   int64
#  2   Maize            2154 non-null   float64
#  3   Rice             2154 non-null   float64
#  4   Yams             2154 non-null   float64
#  5   Wheat            2154 non-null   float64
#  6   Tomatoes         2154 non-null   float64
#  7   Tea              2154 non-null   float64
#  8   Sweet Potatoes   2154 non-null   float64
#  9   Sunflower Seeds  2154 non-null   float64
#  10  Sugar            2154 non-null   float64
#  11  Soybeans         2154 non-null   float64
#  12  Rye              2154 non-null   float64
#  13  Potatoes         2154 non-null   float64
#  14  Oranges          2154 non-null   float64
#  15  Peas             2154 non-null   float64
# ...

# %% [markdown]
# # Bananas
# Banana production has been closeley tied with political and economic developments in South America over the last 150 years.

# %%
from matplotlib.ticker import FuncFormatter

fig, ax = plt.subplots(ncols=3,nrows=2,figsize=(15,8))

countries_banana = {'Afghanistan','Ecuador','United States','France','Dominican Republic','China'}

# Function to format y-axis labels in 'Tonnes'
def tonnage_formatter(value, _):
    return f'{value/1000:.0f} Tonnes'

for i, country in enumerate(countries_banana):
    row = i // 3  # Calculate the row index
    col = i % 3   # Calculate the column index

    # Filter data for the specific country
    country_data = df[df['Country'] == country]

    
    ax[row, col].plot(country_data['Year'], country_data['Bananas'], label=country)
    ax[row, col].set_title(country)
    ax[row, col].set_xlabel('Year')
    ax[row, col].set_ylabel('Banana Production (Tonnes)')

    ax[row, col].yaxis.set_major_formatter(FuncFormatter(tonnage_formatter))

plt.tight_layout()

plt.show()

# %% [markdown]
# Ecuador is one of the biggest exporters of Bananas so something is off with the data, lets dive deeper.

# %%
# Filter the DataFrame for banana data from Ecuador
ecuador_bananas = df.loc[df['Country'] == 'Ecuador', ['Year', 'Bananas']]
# Sort by 'Year' numerically
ecuador_bananas_sorted = ecuador_bananas.sort_values(by='Year')

# Display the sorted DataFrame
print(ecuador_bananas_sorted)
# Out:
#       Year   Bananas
# 3358  1961   6000.00
# 3359  1962   5000.00
# 3360  1963   5000.00
# 3361  1964   5000.00
# 3362  1965   6000.00
# 3363  1966   6000.00
# 3364  1967   6000.00
# 3365  1968   7000.00
# 3366  1969   7000.00
# 3367  1970   7000.00
# 3368  1971   7700.00
# 3369  1972   8000.00
# 3370  1973   8000.00
# 3371  1974   8000.00
# 3372  1975   8000.00
# 3373  1976   8000.00
# 3374  1977   8000.00
# 3375  1978   8000.00
# 3376  1979   8000.00
# 3377  1980   8000.00
# 3378  1981   8000.00
# 3379  1982   8000.00
# 3380  1983   8500.00
# 3381  1984   8500.00
# 3382  1985   8500.00
# 3383  1986   8500.00
# 3384  1987   9000.00
# 3385  1988   9181.81
# 3386  1989   9395.12
# 3387  1990   9605.19
# 3388  1991   9789.23
# 3389  1992  10000.00
# 3390  1993  10236.00
# 3391  1994  10500.00
# 3392  1995  11000.00
# 3393  1996  11500.00
# 3394  1997  12000.00
# 3395  1998  12350.91
# 3396  1999  12618.06
# 3397  2000  12438.77
# 3398  2001  12520.82
# 3399  2002  12011.91
# ...

# %%
# Filter the DataFrame for the year 1964 and exclude countries in the ignore list
banana_1964 = df[(df['Year'] == 1964) & (~df['Country'].isin(country_rows_ignore))]

# Calculate percentages
banana_1964['Percentage'] = banana_1964['Bananas'] / banana_1964['Bananas'].sum() * 100

# Group countries with less than 1% into 'Other, less than 1%'
threshold = 1
banana_1964.loc[banana_1964['Percentage'] < threshold, 'Country'] = 'Other, less than 1%'
banana_1964 = banana_1964.groupby('Country')['Bananas'].sum().reset_index()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(banana_1964['Bananas'], labels=banana_1964['Country'], autopct='%1.1f%%', startangle=90, colors=plt.cm.Set3.colors)
plt.title('Total Banana Production by Country in 1964 (Grouping < 1%)')
plt.show()
# Out:
# C:\Users\israe\AppData\Local\Temp\ipykernel_19368\2859472400.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   banana_1964['Percentage'] = banana_1964['Bananas'] / banana_1964['Bananas'].sum() * 100

# %%
# Filter the DataFrame for the year 2000 and exclude countries in the ignore list
banana_2000 = df[(df['Year'] == 2000) & (~df['Country'].isin(country_rows_ignore))]

# Calculate percentages
banana_2000['Percentage'] = banana_2000['Bananas'] / banana_2000['Bananas'].sum() * 100

# Group countries with less than 1% into 'Other, less than 1%'
threshold = 1
banana_2000.loc[banana_2000['Percentage'] < threshold, 'Country'] = 'Other, less than 1%'
banana_2000 = banana_2000.groupby('Country')['Bananas'].sum().reset_index()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(banana_2000['Bananas'], labels=banana_2000['Country'], autopct='%1.1f%%', startangle=90, colors=plt.cm.Set3.colors)
plt.title('Total Banana Production by Country in 2000 (Grouping < 1%)')
plt.show()
# Out:
# C:\Users\israe\AppData\Local\Temp\ipykernel_19368\490084523.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   banana_2000['Percentage'] = banana_2000['Bananas'] / banana_2000['Bananas'].sum() * 100

# %% [markdown]
# In both of the above charts, Ecuador's banana production doesn't display. Yet, in the years 1964 and 2000, Ecuador exported ~25% and ~28%, respectively, of all the Bananas traded worldwide (https://www.hrw.org/reports/2002/ecuador/ecuad0402-03.htm).

# %% [markdown]
# According to data provided by CONABAN, Ecuador exported 4,543,556 metric tons of bananas from January through November 2000. CONABAN-Ecuador, "La Industria Bananera: . . . ," p. 12

# %%
# Filter the DataFrame for banana data from Ecuador in the year 2000
ecuador_bananas_2000 = df.loc[(df['Country'] == 'Ecuador') & (df['Year'] == 2000), 'Bananas']

# Display the filtered DataFrame
print(ecuador_bananas_2000)
# Out:
# 3397    12438.77
# Name: Bananas, dtype: float64

# %% [markdown]
# # Afghanistan

# %%
afghan_data = df[df['Country'] == 'Afghanistan'].copy()

afghan_data.head()
# Out:
#        Country  Year     Maize      Rice        Yams      Wheat   Tomatoes  \
# 0  Afghanistan  1961  700000.0  319000.0   7467702.0  2279000.0  1873812.0
# 1  Afghanistan  1962  700000.0  319000.0   7420515.0  2279000.0  2044797.0
# 2  Afghanistan  1963  713000.0  319000.0   8479074.0  1947000.0  2096077.0
# 3  Afghanistan  1964  720000.0  380000.0   9113779.0  2230000.0  2388264.0
# 4  Afghanistan  1965  720000.0  380000.0  10067913.0  2282000.0  2559608.0
#
#        Tea  Sweet Potatoes  Sunflower Seeds  ...  Oranges      Peas  \
# 0  56315.0       3270871.0          12000.0  ...  10100.0  232910.0
# 1  61519.0       3562524.0          12800.0  ...  10100.0  259412.0
# 2  63596.0       3409916.0          12800.0  ...  10100.0  251529.0
# 3  66604.0       3229336.0          12800.0  ...  12400.0  247556.0
# 4  72418.0       3169104.0          13200.0  ...  13700.0  266947.0
#
#     Palm Oil    Grapes     Coffee      Cocoa  Chicken    Bananas  Avocados  \
# ...

# %%
afghan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 0 to 60
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          61 non-null     object
#  1   Year             61 non-null     int64
#  2   Maize            61 non-null     float64
#  3   Rice             61 non-null     float64
#  4   Yams             61 non-null     float64
#  5   Wheat            61 non-null     float64
#  6   Tomatoes         61 non-null     float64
#  7   Tea              61 non-null     float64
#  8   Sweet Potatoes   61 non-null     float64
#  9   Sunflower Seeds  61 non-null     float64
#  10  Sugar            61 non-null     float64
#  11  Soybeans         61 non-null     float64
#  12  Rye              61 non-null     float64
#  13  Potatoes         61 non-null     float64
#  14  Oranges          61 non-null     float64
#  15  Peas             61 non-null     float64
# ...

# %%
# Convert 'Year' column to datetime format
afghan_data['Year'] = pd.to_datetime(afghan_data['Year'], format='%Y')

year_counts_sorted = afghan_data['Year'].value_counts().sort_index()

year_counts_sorted.head()
# Out:
# Year
# 1961-01-01    1
# 1962-01-01    1
# 1963-01-01    1
# 1964-01-01    1
# 1965-01-01    1
# Name: count, dtype: int64

# %%
from matplotlib.ticker import StrMethodFormatter


plt.figure(figsize=(15,10))

columns_to_plot = afghan_data.loc[:, ~afghan_data.columns.isin(['Country', 'Year'])]

color_map = plt.cm.get_cmap('tab20', len(columns_to_plot.columns))

for i, column in enumerate(columns_to_plot.columns):
    plt.plot(afghan_data['Year'], columns_to_plot[column], label=column, color=color_map(i))

plt.xlabel('Year')
plt.ylabel('Tonnes Produced')
plt.title('Production over Time')
plt.legend()

plt.gca().get_yaxis().set_major_formatter(StrMethodFormatter('{x:,.0f}'))

plt.show()
# Out:
# /var/folders/7q/5gg1h2qn395d6bb79wt_xlch0000gn/T/ipykernel_10017/394821462.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   color_map = plt.cm.get_cmap('tab20', len(columns_to_plot.columns))

# %%
plt.figure(figsize=(15,10))

columns_to_plot = 'Yams','Tomatoes','Sweet Potatoes','Bananas'


for column in columns_to_plot:
    plt.plot(afghan_data['Year'],afghan_data[column], label = column)

plt.xlabel('Year')
plt.ylabel('Tonnes Produced')
plt.title('Production over Time')
plt.legend()

plt.gca().get_yaxis().set_major_formatter(StrMethodFormatter('{x:,.0f}'))

plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf

plt.figure(figsize=(12, 6))
for column in columns_to_plot:
    plot_acf(afghan_data[column], lags=30, title= f'Autocorrelation Plot for {column}')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA
from pandas import DataFrame

arima_columns = afghan_data.loc[:, ~afghan_data.columns.isin(['Country'])]

model = ARIMA(arima_columns['Yams'],order=(20,1,0))
model_fit = model.fit()

print(model_fit.summary())


residuals = DataFrame(model_fit.resid)
residuals.plot()
plt.show()
# density plot of residuals
residuals.plot(kind='kde')
plt.show()
# summary stats of residuals
print(residuals.describe())
# Out:
# /Users/israeldellinger/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
#                                SARIMAX Results
# ...
# Dep. Variable:                   Yams   No. Observations:                   61
# Model:                ARIMA(20, 1, 0)   Log Likelihood                -962.514
# Date:                Mon, 15 Jan 2024   AIC                           1967.029
# Time:                        09:36:31   BIC                           2011.010
# Sample:                             0   HQIC                          1984.232
#                                  - 61
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
